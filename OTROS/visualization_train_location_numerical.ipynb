# %%
import pandas as pd
import numpy as np

# %%
train_location_numerical = pd.read_csv('train_location_numerical.csv')
train_location_numerical
# Out:
#          id  target  has_country  has_city  has_county  has_state  \
# 0         1       1            0         0           0          0
# 1         4       1            0         0           0          0
# 2         5       1            0         0           0          0
# 3         6       1            0         0           0          0
# 4         7       1            0         0           0          0
# ...     ...     ...          ...       ...         ...        ...
# 7608  10869       1            0         0           0          0
# 7609  10870       1            0         0           0          0
# 7610  10871       1            0         0           0          0
# 7611  10872       1            0         0           0          0
# 7612  10873       1            0         0           0          0
#
#       has_continent
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 7608              0
# ...

# %%
train_location_numerical = train_location_numerical.groupby('target').agg({'has_country':'sum', 'has_city':'sum','has_state':'sum', 'has_county':'sum', 'has_continent':'sum'})
train_location_numerical
# Out:
#         has_country  has_city  has_state  has_county  has_continent
# target
# 0              1444       856        342           6           1449
# 1              1258       640        291          15           1270

# %%
train_location_numerical.plot(kind = 'bar', figsize = [12,9])
